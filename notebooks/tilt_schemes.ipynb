# %%
import sys
import matplotlib.pyplot as plt
sys.path.append("/mnt/storage/documents/IBS_PhD/programming/ABTT") 
from ABTT.tilt_scheme import tilt_scheme

# %%
fig, axes = plt.subplots(1,3)
fig.set_size_inches(15,4)

ts = tilt_scheme.TiltScheme()
ts.angles_continuous(-60,60,3)
ts.sort_angles(reverse=True)
ts.lines()
ts.plot_lines(cmap='Blues_r', ax=axes[0])

ts = tilt_scheme.TiltScheme()
ts.angles_bidirectional(60,3)
ts.sort_angles(reverse=True)
ts.lines()
ts.plot_lines(cmap='Blues_r', ax=axes[1])

ts = tilt_scheme.TiltScheme()
ts.angles_dose_symmetric(60,3)
ts.sort_angles()
ts.lines()
ts.plot_lines(cmap='Blues_r', ax=axes[2])

# %%
ts = tilt_scheme.TiltScheme()
ts.angles_dose_symmetric(60,3)
ts.sort_angles()
ts.lines()
ts.plot_lines(cmap='Blues_r', cbar=True)
