# %% [markdown]
# ### Import Necessary libraries

# %%
import sys
import matplotlib.pyplot as plt
sys.path.append("/mnt/storage/documents/IBS_PhD/programming/ABTT") 
import ABTT.fsc.relion as relion_fsc

# %% [markdown]
# ### Read star file and create plotter object

# %%
star_file = '/mnt/storage/documents/IBS_PhD/programming/ABTT/ABTT/tests/example_data/fsc/postprocess.star'

# %%
# %matplotlib inline
plotter = relion_fsc.Plotter(star_file)
# Out:
# WARNING:root:one or more data blocks in this star file are unsupported

# %% [markdown]
# ### Standard usage should generate a clean plot

# %%
plotter.plot()
# Out:
# /mnt/storage/documents/IBS_PhD/programming/ABTT/ABTT/math/spatial_frequency.py:12: RuntimeWarning: divide by zero encountered in double_scalars
#   resolution_angstroms = 1.0 / spatial_frequency_angstroms

# %% [markdown]
# ### Many parameters are adjustable

# %%
plotter.plot(hide_spines=False,
             legend=True,
             plot_cutoff_0143=True,
             plot_cutoff_05=False,
             plot_zero_line=True,
             reported_resolution_precision=8,
             xaxis_precision=3)
# Out:
# /mnt/storage/documents/IBS_PhD/programming/ABTT/ABTT/math/spatial_frequency.py:12: RuntimeWarning: divide by zero encountered in double_scalars
#   resolution_angstroms = 1.0 / spatial_frequency_angstroms

# %% [markdown]
# ### Files can be saved
# - set the file_out argument equal to your desired filename. format will be inferred from filename or default to svg

# %%
plotter.plot(file_out='test.svg')
# Out:
# /mnt/storage/documents/IBS_PhD/programming/ABTT/ABTT/math/spatial_frequency.py:12: RuntimeWarning: divide by zero encountered in double_scalars
#   resolution_angstroms = 1.0 / spatial_frequency_angstroms
